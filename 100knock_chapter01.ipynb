# %%
import pandas as pd
uriage_data = pd.read_csv('C:\\Users\\user\\jupyter\\100knock-data_analytics\\2章\\uriage.csv')
kokyaku_data = pd.read_excel('C:\\Users\\user\\jupyter\\100knock-data_analytics\\2章\\kokyaku_daicho.xlsx')

# %%
kokyaku_data.head()
# Out:
#       顧客名        かな  地域                     メールアドレス         登録日
# 0   須賀ひとみ    すが ひとみ  H市     suga_hitomi@example.com  2018/01/04
# 1  岡田　 敏也   おかだ としや  E市   okada_toshiya@example.com       42782
# 2    芳賀 希    はが のぞみ  A市     haga_nozomi@example.com  2018/01/07
# 3   荻野  愛    おぎの あい  F市        ogino_ai@example.com       42872
# 4   栗田 憲一  くりた けんいち  E市  kurita_kenichi@example.com       43127

# %%
uriage_data.head()
# Out:
#          purchase_date item_name  item_price customer_name
# 0  2019-06-13 18:02:34       商品A       100.0         深井菜々美
# 1  2019-07-13 13:05:29     商 品 S         NaN          浅田賢二
# 2  2019-05-11 19:42:07     商 品 a         NaN          南部慶二
# 3  2019-02-12 23:40:45       商品Z      2600.0          麻生莉緒
# 4  2019-04-22 03:09:35       商品a         NaN          平田鉄二

# %%
uriage_data.dtypes
# Out:
# purchase_date     object
# item_name         object
# item_price       float64
# customer_name     object
# dtype: object

# %%
uriage_data['purchase_date'] = pd.to_datetime(uriage_data['purchase_date'])
uriage_data['purchase_month'] = uriage_data['purchase_date'].dt.strftime('%Y%m')
uriage_data
# Out:
#            purchase_date item_name  item_price customer_name purchase_month
# 0    2019-06-13 18:02:34       商品A       100.0         深井菜々美         201906
# 1    2019-07-13 13:05:29     商 品 S         NaN          浅田賢二         201907
# 2    2019-05-11 19:42:07     商 品 a         NaN          南部慶二         201905
# 3    2019-02-12 23:40:45       商品Z      2600.0          麻生莉緒         201902
# 4    2019-04-22 03:09:35       商品a         NaN          平田鉄二         201904
# ...                  ...       ...         ...           ...            ...
# 2994 2019-02-15 02:56:39       商品Y      2500.0          福島友也         201902
# 2995 2019-06-22 04:03:43       商品M      1300.0          大倉晃司         201906
# 2996 2019-03-29 11:14:05       商品Q         NaN          尾形小雁         201903
# 2997 2019-07-14 12:56:49       商品H         NaN          芦田博之         201907
# 2998 2019-07-21 00:31:36       商品D       400.0          石田郁恵         201907
#
# [2999 rows x 5 columns]

# %%
pd.pivot_table(uriage_data, columns='item_name', index='purchase_month', values='item_price', aggfunc='sum')
# Out:
# item_name          商品W   商 品 n    商品E     商品M     商品P     商品S     商品W     商品X  \
# purchase_month
# 201901             NaN  1400.0    NaN     NaN     NaN     NaN     NaN     NaN
# 201902             NaN     NaN    NaN     NaN     NaN     NaN     NaN  2400.0
# 201903             NaN     NaN  500.0  1300.0  1600.0     NaN     NaN     NaN
# 201904          2300.0     NaN    NaN     NaN     NaN     NaN     NaN     NaN
# 201905             NaN     NaN    NaN     NaN     NaN  1900.0     NaN     NaN
# 201906             NaN     NaN    NaN     NaN     NaN     NaN  2300.0     NaN
# 201907             NaN     NaN    NaN     NaN     NaN     NaN     NaN     NaN
#
# item_name       商  品O   商  品Q  ...     商品k     商品l     商品o     商品p     商品r  \
# purchase_month                 ...
# 201901            NaN     NaN  ...  1100.0  1200.0  1500.0     NaN     NaN
# 201902            NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# ...

# %%
len(pd.unique(uriage_data['item_name']))
# Out:
# 99

# %%
uriage_data['item_name'] = uriage_data['item_name'].str.upper()
uriage_data['item_name'] = uriage_data['item_name'].str.replace(' ','')
uriage_data['item_name'] = uriage_data['item_name'].str.replace('　','')
uriage_data
# Out:
#            purchase_date item_name  item_price customer_name purchase_month
# 0    2019-06-13 18:02:34       商品A       100.0         深井菜々美         201906
# 1    2019-07-13 13:05:29       商品S         NaN          浅田賢二         201907
# 2    2019-05-11 19:42:07       商品A         NaN          南部慶二         201905
# 3    2019-02-12 23:40:45       商品Z      2600.0          麻生莉緒         201902
# 4    2019-04-22 03:09:35       商品A         NaN          平田鉄二         201904
# ...                  ...       ...         ...           ...            ...
# 2994 2019-02-15 02:56:39       商品Y      2500.0          福島友也         201902
# 2995 2019-06-22 04:03:43       商品M      1300.0          大倉晃司         201906
# 2996 2019-03-29 11:14:05       商品Q         NaN          尾形小雁         201903
# 2997 2019-07-14 12:56:49       商品H         NaN          芦田博之         201907
# 2998 2019-07-21 00:31:36       商品D       400.0          石田郁恵         201907
#
# [2999 rows x 5 columns]

# %%
len(pd.unique(uriage_data['item_name']))
# Out:
# 26

# %%
flg_is_null = uriage_data['item_price'].isnull()
flg_is_null
# Out:
# 0       False
# 1        True
# 2        True
# 3       False
# 4        True
#         ...
# 2994    False
# 2995    False
# 2996     True
# 2997     True
# 2998    False
# Name: item_price, Length: 2999, dtype: bool

# %%
list(uriage_data.loc[flg_is_null, 'item_name'].unique())
# Out:
# ['商品S',
#  '商品A',
#  '商品P',
#  '商品N',
#  '商品W',
#  '商品R',
#  '商品I',
#  '商品L',
#  '商品F',
#  '商品O',
#  '商品B',
#  '商品C',
#  '商品V',
#  '商品Q',
#  '商品U',
#  '商品K',
#  '商品T',
#  '商品X',
#  '商品E',
#  '商品M',
#  '商品G',
#  '商品J',
#  '商品D',
#  '商品H',
#  '商品Y']

# %%
for trg in list(uriage_data.loc[flg_is_null, 'item_name'].unique()):
    price = uriage_data.loc[(~flg_is_null)&(uriage_data['item_name'] == trg), 'item_price'].max()
    uriage_data.loc[(flg_is_null)&(uriage_data['item_name'] == trg) ,'item_price'] = price

# %%
uriage_data.isnull().any()
# Out:
# purchase_date     False
# item_name         False
# item_price        False
# customer_name     False
# purchase_month    False
# dtype: bool

# %%
for trg in list(uriage_data['item_name'].sort_values().unique()):
    print(f'商品名{trg}の最大値は{uriage_data.loc[(uriage_data['item_name'] == trg), 'item_price'].max()}、最小値は{uriage_data.loc[(uriage_data['item_name'] == trg), 'item_price'].min()}')
# Out:
# 商品名商品Aの最大値は100.0、最小値は100.0
# 商品名商品Bの最大値は200.0、最小値は200.0
# 商品名商品Cの最大値は300.0、最小値は300.0
# 商品名商品Dの最大値は400.0、最小値は400.0
# 商品名商品Eの最大値は500.0、最小値は500.0
# 商品名商品Fの最大値は600.0、最小値は600.0
# 商品名商品Gの最大値は700.0、最小値は700.0
# 商品名商品Hの最大値は800.0、最小値は800.0
# 商品名商品Iの最大値は900.0、最小値は900.0
# 商品名商品Jの最大値は1000.0、最小値は1000.0
# 商品名商品Kの最大値は1100.0、最小値は1100.0
# 商品名商品Lの最大値は1200.0、最小値は1200.0
# 商品名商品Mの最大値は1300.0、最小値は1300.0
# 商品名商品Nの最大値は1400.0、最小値は1400.0
# 商品名商品Oの最大値は1500.0、最小値は1500.0
# 商品名商品Pの最大値は1600.0、最小値は1600.0
# 商品名商品Qの最大値は1700.0、最小値は1700.0
# 商品名商品Rの最大値は1800.0、最小値は1800.0
# 商品名商品Sの最大値は1900.0、最小値は1900.0
# 商品名商品Tの最大値は2000.0、最小値は2000.0
# 商品名商品Uの最大値は2100.0、最小値は2100.0
# 商品名商品Vの最大値は2200.0、最小値は2200.0
# 商品名商品Wの最大値は2300.0、最小値は2300.0
# 商品名商品Xの最大値は2400.0、最小値は2400.0
# 商品名商品Yの最大値は2500.0、最小値は2500.0
# 商品名商品Zの最大値は2600.0、最小値は2600.0

# %%
tmp_list = []
for trg in list(uriage_data.loc[flg_is_null, 'item_name'].unique()):
    if uriage_data.loc[(~flg_is_null)&(uriage_data['item_name'] == trg), 'item_price'].max() == uriage_data.loc[(~flg_is_null)&(uriage_data['item_name'] == trg), 'item_price'].min():
        tmp_list.append('ok')
    else:
        print(f'{trg}でエラー発生')
if len(tmp_list) == len(uriage_data.loc[flg_is_null, 'item_name'].unique()):
    print(True)
# Out:
# True

# %%
kokyaku_data['顧客名'].head()
# Out:
# 0     須賀ひとみ
# 1    岡田　 敏也
# 2      芳賀 希
# 3     荻野  愛
# 4     栗田 憲一
# Name: 顧客名, dtype: object

# %%
uriage_data['customer_name']
# Out:
# 0       深井菜々美
# 1        浅田賢二
# 2        南部慶二
# 3        麻生莉緒
# 4        平田鉄二
#         ...
# 2994     福島友也
# 2995     大倉晃司
# 2996     尾形小雁
# 2997     芦田博之
# 2998     石田郁恵
# Name: customer_name, Length: 2999, dtype: object

# %%
kokyaku_data['顧客名'] = kokyaku_data['顧客名'].str.replace(' ','')
kokyaku_data['顧客名'] = kokyaku_data['顧客名'].str.replace('　','')

# %%
kokyaku_data['顧客名'].head()
# Out:
# 0    須賀ひとみ
# 1     岡田敏也
# 2      芳賀希
# 3      荻野愛
# 4     栗田憲一
# Name: 顧客名, dtype: object

# %%
kokyaku_data['登録日']
# Out:
# 0      2018/01/04
# 1           42782
# 2      2018/01/07
# 3           42872
# 4           43127
#           ...
# 195    2017/06/20
# 196    2018/06/20
# 197    2017/04/29
# 198    2019/04/19
# 199    2019/04/23
# Name: 登録日, Length: 200, dtype: object

# %%
kokyaku_data['登録日'].astype('str')
# Out:
# 0      2018/01/04
# 1           42782
# 2      2018/01/07
# 3           42872
# 4           43127
#           ...
# 195    2017/06/20
# 196    2018/06/20
# 197    2017/04/29
# 198    2019/04/19
# 199    2019/04/23
# Name: 登録日, Length: 200, dtype: object

# %%
flg_is_serial = kokyaku_data['登録日'].astype('str').str.isdigit()
flg_is_serial.sum()
# Out:
# 22

# %%
fromSerial = pd.to_timedelta(kokyaku_data.loc[flg_is_serial, '登録日'].astype('float')-2, unit='D') + pd.to_datetime('1900/1/1')
fromSerial
# Out:
# 1     2017-02-16
# 3     2017-05-17
# 4     2018-01-27
# 21    2017-07-04
# 27    2017-06-15
# 47    2017-01-06
# 49    2017-07-13
# 53    2017-04-08
# 76    2018-03-29
# 80    2018-01-10
# 99    2017-05-30
# 114   2018-06-03
# 118   2018-01-29
# 122   2018-04-16
# 139   2017-05-25
# 143   2017-03-24
# 155   2017-01-19
# 172   2018-03-22
# 179   2017-01-08
# 183   2017-07-24
# 186   2018-07-13
# 192   2018-06-08
# Name: 登録日, dtype: datetime64[ns]

# %%
fromString = pd.to_datetime(kokyaku_data.loc[~flg_is_serial, '登録日'])
fromString
# Out:
# 0     2018-01-04
# 2     2018-01-07
# 5     2017-06-20
# 6     2018-06-11
# 7     2017-05-19
#          ...
# 195   2017-06-20
# 196   2018-06-20
# 197   2017-04-29
# 198   2019-04-19
# 199   2019-04-23
# Name: 登録日, Length: 178, dtype: datetime64[ns]

# %%
kokyaku_data['登録日'] = pd.concat([fromSerial, fromString])
kokyaku_data
# Out:
#        顧客名           かな  地域                         メールアドレス        登録日
# 0    須賀ひとみ       すが ひとみ  H市         suga_hitomi@example.com 2018-01-04
# 1     岡田敏也      おかだ としや  E市       okada_toshiya@example.com 2017-02-16
# 2      芳賀希       はが のぞみ  A市         haga_nozomi@example.com 2018-01-07
# 3      荻野愛       おぎの あい  F市            ogino_ai@example.com 2017-05-17
# 4     栗田憲一     くりた けんいち  E市      kurita_kenichi@example.com 2018-01-27
# ..     ...          ...  ..                             ...        ...
# 195   川上りえ      かわかみ りえ  G市        kawakami_rie@example.com 2017-06-20
# 196   小松季衣      こまつ としえ  E市      komatsu_toshie@example.com 2018-06-20
# 197   白鳥りえ      しらとり りえ  F市       shiratori_rie@example.com 2017-04-29
# 198  大西隆之介  おおにし りゅうのすけ  H市  oonishi_ryuunosuke@example.com 2019-04-19
# 199   福井美希       ふくい みき  D市         fukui_miki1@example.com 2019-04-23
#
# [200 rows x 5 columns]

# %%
kokyaku_data['登録年月'] = kokyaku_data['登録日'].dt.strftime('%Y%m')
kokyaku_data.head(3)
# Out:
#      顧客名       かな  地域                    メールアドレス        登録日    登録年月
# 0  須賀ひとみ   すが ひとみ  H市    suga_hitomi@example.com 2018-01-04  201801
# 1   岡田敏也  おかだ としや  E市  okada_toshiya@example.com 2017-02-16  201702
# 2    芳賀希   はが のぞみ  A市    haga_nozomi@example.com 2018-01-07  201801

# %%
kokyaku_data.groupby('登録年月').count()['顧客名']
# Out:
# 登録年月
# 201701    15
# 201702    11
# 201703    14
# 201704    15
# 201705    14
# 201706    13
# 201707    17
# 201801    13
# 201802    15
# 201803    17
# 201804     5
# 201805    19
# 201806    13
# 201807    17
# 201904     2
# Name: 顧客名, dtype: int64

# %%
join_data = pd.merge(uriage_data, kokyaku_data, left_on='customer_name', right_on='顧客名', how='left')
join_data.head()
# Out:
#         purchase_date item_name  item_price customer_name purchase_month  \
# 0 2019-06-13 18:02:34       商品A       100.0         深井菜々美         201906
# 1 2019-07-13 13:05:29       商品S      1900.0          浅田賢二         201907
# 2 2019-05-11 19:42:07       商品A       100.0          南部慶二         201905
# 3 2019-02-12 23:40:45       商品Z      2600.0          麻生莉緒         201902
# 4 2019-04-22 03:09:35       商品A       100.0          平田鉄二         201904
#
#      顧客名       かな  地域                     メールアドレス        登録日    登録年月
# 0  深井菜々美  ふかい ななみ  C市    fukai_nanami@example.com 2017-01-26  201701
# 1   浅田賢二  あさだ けんじ  C市     asada_kenji@example.com 2018-04-07  201804
# 2   南部慶二  なんぶ けいじ  A市    nannbu_keiji@example.com 2018-06-19  201806
# 3   麻生莉緒   あそう りお  D市        asou_rio@example.com 2018-07-22  201807
# 4   平田鉄二  ひらた てつじ  D市  hirata_tetsuji@example.com 2017-06-07  201706

# %%
dump_data = join_data[['purchase_date','purchase_month','item_name','item_price','顧客名','かな','地域','メールアドレス','登録日']]
dump_data.head()
# Out:
#         purchase_date purchase_month item_name  item_price    顧客名       かな  \
# 0 2019-06-13 18:02:34         201906       商品A       100.0  深井菜々美  ふかい ななみ
# 1 2019-07-13 13:05:29         201907       商品S      1900.0   浅田賢二  あさだ けんじ
# 2 2019-05-11 19:42:07         201905       商品A       100.0   南部慶二  なんぶ けいじ
# 3 2019-02-12 23:40:45         201902       商品Z      2600.0   麻生莉緒   あそう りお
# 4 2019-04-22 03:09:35         201904       商品A       100.0   平田鉄二  ひらた てつじ
#
#    地域                     メールアドレス        登録日
# 0  C市    fukai_nanami@example.com 2017-01-26
# 1  C市     asada_kenji@example.com 2018-04-07
# 2  A市    nannbu_keiji@example.com 2018-06-19
# 3  D市        asou_rio@example.com 2018-07-22
# 4  D市  hirata_tetsuji@example.com 2017-06-07

# %%
dump_data.to_csv('dump_data.csv', index=False)

# %%
import_data = pd.read_csv('dump_data.csv')
import_data.head()
# Out:
#          purchase_date  purchase_month item_name  item_price    顧客名       かな  \
# 0  2019-06-13 18:02:34          201906       商品A       100.0  深井菜々美  ふかい ななみ
# 1  2019-07-13 13:05:29          201907       商品S      1900.0   浅田賢二  あさだ けんじ
# 2  2019-05-11 19:42:07          201905       商品A       100.0   南部慶二  なんぶ けいじ
# 3  2019-02-12 23:40:45          201902       商品Z      2600.0   麻生莉緒   あそう りお
# 4  2019-04-22 03:09:35          201904       商品A       100.0   平田鉄二  ひらた てつじ
#
#    地域                     メールアドレス         登録日
# 0  C市    fukai_nanami@example.com  2017-01-26
# 1  C市     asada_kenji@example.com  2018-04-07
# 2  A市    nannbu_keiji@example.com  2018-06-19
# 3  D市        asou_rio@example.com  2018-07-22
# 4  D市  hirata_tetsuji@example.com  2017-06-07

# %%
import_data.shape
# Out:
# (2999, 9)

# %%
byItem = import_data.pivot_table(index = 'purchase_month', columns = 'item_name', aggfunc='size', fill_value=0)
byItem
# Out:
# item_name       商品A  商品B  商品C  商品D  商品E  商品F  商品G  商品H  商品I  商品J  ...  商品Q  \
# purchase_month                                                    ...
# 201901           18   13   19   17   18   15   11   16   18   17  ...   17
# 201902           19   14   26   21   16   14   14   17   12   14  ...   22
# 201903           17   21   20   17    9   27   14   18   12   16  ...   23
# 201904           17   19   24   20   18   17   14   11   18   13  ...   20
# 201905           24   14   16   14   19   18   23   15   16   11  ...   13
# 201906           24   12   11   19   13   18   15   13   19   22  ...   15
# 201907           20   20   17   17   12   17   19   19   19   23  ...   15
#
# item_name       商品R  商品S  商品T  商品U  商品V  商品W  商品X  商品Y  商品Z
# purchase_month
# 201901           21   20   17    7   22   13   14   10    0
# 201902           22   22   23   19   22   24   16   11    1
# 201903           16   20   12   23   18   16   21   16    0
# ...

# %%
140*26
# Out:
# 3640

# %%
byPrice = import_data.pivot_table(index='purchase_month', columns='item_price', aggfunc='size', fill_value=0)
byPrice
# Out:
# item_price      100.0   200.0   300.0   400.0   500.0   600.0   700.0   \
# purchase_month
# 201901              18      13      19      17      18      15      11
# 201902              19      14      26      21      16      14      14
# 201903              17      21      20      17       9      27      14
# 201904              17      19      24      20      18      17      14
# 201905              24      14      16      14      19      18      23
# 201906              24      12      11      19      13      18      15
# 201907              20      20      17      17      12      17      19
#
# item_price      800.0   900.0   1000.0  ...  1700.0  1800.0  1900.0  2000.0  \
# purchase_month                          ...
# 201901              16      18      17  ...      17      21      20      17
# 201902              17      12      14  ...      22      22      22      23
# 201903              18      12      16  ...      23      16      20      12
# ...

# %%
byCustomer = import_data.pivot_table(index='purchase_month', columns='顧客名', aggfunc='size', fill_value=0)
byCustomer
# Out:
# 顧客名             さだ千佳子  中仁晶  中田美智子  丸山光臣  久保田倫子  亀井一徳  五十嵐春樹  井上桃子  井口寛治  \
# purchase_month
# 201901              3    1      4     2      2     0      5     3     3
# 201902              9    1      2     2      1     4      2     1     0
# 201903              1    2      1     6      1     4      3     3     2
# 201904              0    3      1     2      0     2      2     0     3
# 201905              3    2      5     2      4     1      2     1     3
# 201906              1    3      0     4      1     1      1     2     2
# 201907              3    0      3     2      5     3      5     2     5
#
# 顧客名             井川真悠子  ...  香椎優一  高原充則  高梨結衣  高沢美咲  高田さんま  鳥居広司  鶴岡薫  麻生莉緒  \
# purchase_month         ...
# 201901              1  ...     0     1     1     1      5     2    0     2
# 201902              4  ...     4     0     3     2      0     1    2     4
# 201903              2  ...     3     1     6     2      4     2    4     2
# ...

# %%
byRigion = import_data.pivot_table(index='purchase_month', columns='地域', aggfunc='size', fill_value=0)
byRigion
# Out:
# 地域              A市  B市  C市  D市  E市  F市  G市  H市
# purchase_month
# 201901          59  55  72  34  49  57  49  42
# 201902          71  46  65  48  61  52  43  63
# 201903          64  52  57  43  52  59  51  59
# 201904          64  48  54  45  48  58  40  52
# 201905          57  52  68  48  59  65  35  43
# 201906          53  47  61  30  51  51  58  58
# 201907          76  53  61  42  54  64  47  54

# %%
away_data = pd.merge(uriage_data, kokyaku_data, left_on='customer_name', right_on='顧客名', how='right')
away_data[away_data['purchase_date'].isnull()].iloc[:,5:]
# Out:
#        顧客名      かな  地域                  メールアドレス        登録日    登録年月
# 2999  福井美希  ふくい みき  D市  fukui_miki1@example.com 2019-04-23  201904

# %%
uselog = pd.read_csv('C:\\Users\\user\\jupyter\\100knock-data_analytics\\3章\\use_log.csv')
customer = pd.read_csv('C:\\Users\\user\\jupyter\\100knock-data_analytics\\3章\\customer_master.csv')
class_master = pd.read_csv('C:\\Users\\user\\jupyter\\100knock-data_analytics\\3章\\class_master.csv')
campaign_master = pd.read_csv('C:\\Users\\user\\jupyter\\100knock-data_analytics\\3章\\campaign_master.csv')
