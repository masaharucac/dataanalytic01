# %%
import pandas as pd
df = pd.read_csv('chap5.csv')

# 各列の平均値を計算して、colmeanに代入
colmean = df.mean(numeric_only=True)

# 平均値で欠損値を穴埋めしてdf2に代入
df2 = df.fillna(colmean)

item=['がく片長さ','がく片幅','花弁長さ','花弁幅']
x=df2[item]
t=df2['種類']

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,t,test_size=0.3,random_state=0)

from sklearn import tree
model=tree.DecisionTreeClassifier(max_depth=2,random_state=0)
model.fit(x_train,y_train)
model.score(x_test,y_test)
import pickle
with open ('irismodel.pkl','wb') as f:
    pickle.dump(model,f)


x_train.clumns=['gakunagasa','gaku_haba','kaben_nagasa','kaben_haba']
from sklearn.tree import plot_tree
plot_tree(model, feature_names=x_train.columns,filled=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_15252\1623340846.py:26: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   x_train.clumns=['gakunagasa','gaku_haba','kaben_nagasa','kaben_haba']
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\tree\_export.py:665: UserWarning: Glyph 33457 (\N{CJK UNIFIED IDEOGRAPH-82B1}) missing from current font.
#   ann.update_bbox_position_size(renderer)
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\tree\_export.py:665: UserWarning: Glyph 24321 (\N{CJK UNIFIED IDEOGRAPH-5F01}) missing from current font.
#   ann.update_bbox_position_size(renderer)
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\tree\_export.py:665: UserWarning: Glyph 24133 (\N{CJK UNIFIED IDEOGRAPH-5E45}) missing from current font.
#   ann.update_bbox_position_size(renderer)
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 model.classe_
#
# AttributeError: 'DecisionTreeClassifier' object has no attribute 'classe_'

# %%
import pandas as pd
df=pd.read_csv('chap5pr.csv')
df.head(3)
# Out:
#          x0        x1        x2        x3  target
# 0 -1.244674  1.452124 -1.184385 -0.839169       1
# 1 -1.662920 -0.375804 -0.956673  0.380114       0
# 2 -1.926513       NaN -1.203904 -0.728801       1

# %%
import pandas as pd
df=pd.read_csv('chap5pr.csv')
df.head(3)
df.shape
# Out:
# (100, 5)

# %%
import pandas as pd
df=pd.read_csv('chap5pr.csv')
df.head(3)
df.shape
df['target'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
import pandas as pd
df=pd.read_csv('chap5pr.csv')
df.head(3)
df.shape
df['target'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
import pandas as pd
df=pd.read_csv('chap5pr.csv')
df.head(3)
df.shape
df['target'].unique()
df['target'].value_counts()
# Out:
# target
# 1    80
# 0    20
# Name: count, dtype: int64

# %%
import pandas as pd
df=pd.read_csv('chap5pr.csv')
df.head(3)
df.shape
df['target'].unique()
df['target'].value_counts()
x_item=['x0','x1','x2','x3']
df.isnull().sum()
colmean=df.median()
df2=df.fillna(colmean)
df2.isnull().any(axis=0)
# Out:
# x0        False
# x1        False
# x2        False
# x3        False
# target    False
# dtype: bool

# %%
import pandas as pd
df=pd.read_csv('chap5pr.csv')
df.head(3)
df.shape
df['target'].unique()
df['target'].value_counts()
x_item=['x0','x1','x2','x3']
df.isnull().sum()
colmean=df.median()
df2=df.fillna(colmean)
df2.isnull().any(axis=0)
# Out:
# x0        False
# x1        False
# x2        False
# x3        False
# target    False
# dtype: bool

# %%
import pandas as pd
df=pd.read_csv('chap5pr.csv')
df.head(3)
df.shape
df['target'].unique()
df['target'].value_counts()
x_item=['x0','x1','x2','x3']
df.isnull().sum()
colmean=df.median()
df2=df.fillna(colmean)
df2.isnull().any(axis=0)
x=df2[x_item]
t=df2['target']
# Out:
# 0     1
# 1     0
# 2     1
# 3     0
# 4     1
#      ..
# 95    1
# 96    1
# 97    1
# 98    1
# 99    1
# Name: target, Length: 100, dtype: int64

# %%
import pandas as pd
df=pd.read_csv('chap5pr.csv')
df.head(3)
df.shape
df['target'].unique()
df['target'].value_counts()
x_item=['x0','x1','x2','x3']
df.isnull().sum()
colmean=df.median()
df2=df.fillna(colmean)
df2.isnull().any(axis=0)
x=df2[x_item]
t=df2['target']

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,t,test_size=0.2,random_state=0)
# Out:
# 0     1
# 1     0
# 2     1
# 3     0
# 4     1
#      ..
# 95    1
# 96    1
# 97    1
# 98    1
# 99    1
# Name: target, Length: 100, dtype: int64

# %%
import pandas as pd
df=pd.read_csv('chap5pr.csv')
df.head(3)
df.shape
df['target'].unique()
df['target'].value_counts()
x_item=['x0','x1','x2','x3']
df.isnull().sum()
colmean=df.median()
df2=df.fillna(colmean)
df2.isnull().any(axis=0)
x=df2[x_item]
t=df2['target']

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,t,test_size=0.2,random_state=0)
from sklearn import tree
model=tree.DecisionTreeClassifier(max_depth=3,random_state=0)
model.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# 0.95

# %%
import pandas as pd
df=pd.read_csv('chap5pr.csv')
df.head(3)
df.shape
df['target'].unique()
df['target'].value_counts()
x_item=['x0','x1','x2','x3']
df.isnull().sum()
colmean=df.median()
df2=df.fillna(colmean)
df2.isnull().any(axis=0)
x=df2[x_item]
t=df2['target']

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,t,test_size=0.2,random_state=0)
from sklearn import tree
model=tree.DecisionTreeClassifier(max_depth=3,random_state=0)
model.fit(x_train,y_train)

answer=model.predict([[1.56,0.23,-1.1,-2.8]])
answer
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)
