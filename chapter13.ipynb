# %%
import pandas as pd

df=pd.read_csv('cinema.csv')
df=df.fillna(df.mean())
x=df.loc[:, 'SNS1':'original']
t=df['sales']
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x,t)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error

pred = model.predict(x)

mse = mean_squared_error(pred, t)
mse
# Out:
# 151986.03957624518

# %%
import math
math.sqrt(mse)
# Out:
# 389.85386951554705

# %%
df2=pd.read_csv('Survived.csv')
df2
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0              1         0       3    male  22.0      1      0
# 1              2         1       1  female  38.0      1      0
# 2              3         1       3  female  26.0      0      0
# 3              4         1       1  female  35.0      1      0
# 4              5         0       3    male  35.0      0      0
# ..           ...       ...     ...     ...   ...    ...    ...
# 886          887         0       2    male  27.0      0      0
# 887          888         1       1  female  19.0      0      0
# 888          889         0       3  female   NaN      1      2
# 889          890         1       1    male  26.0      0      0
# 890          891         0       3    male  32.0      0      0
#
#                Ticket     Fare Cabin Embarked
# 0           A/5 21171   7.2500   NaN        S
# 1            PC 17599  71.2833   C85        C
# 2    STON/O2. 3101282   7.9250   NaN        S
# 3              113803  53.1000  C123        S
# 4              373450   8.0500   NaN        S
# ..                ...      ...   ...      ...
# 886            211536  13.0000   NaN        S
# 887            112053  30.0000   B42        S
# 888        W./C. 6607  23.4500   NaN        S
# 889            111369  30.0000  C148        C
# 890            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
import pandas as pd
df=pd.read_csv('cinema.csv')
df=df.fillna(df.mean())
x=df.loc[:, 'SNS1':'original']
t=df['sales']

# %%
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression
kf=KFold(n_splits=3, shuffle=True, random_state=0)

from sklearn.model_selection import cross_validate
model=LinearRegression()
result=cross_validate(model, x, t, cv=kf, scoring='r2', return_train_score=True)
print(result)
# Out:
# {'fit_time': array([0.00867581, 0.00959706, 0.00480056]), 'score_time': array([0.00234127, 0.00360203, 0.        ]), 'test_score': array([0.72465051, 0.71740834, 0.75975591]), 'train_score': array([0.76928501, 0.76368104, 0.75780074])}

# %%
sum(result['test_score']) / len(result['test_score'])
# Out:
# 0.7339382541774341

# %%
from sklearn.model_selection import StratifiedKFold

skf=StratifiedKFold(n_splits=3, shuffle=True, random_state=0)

# %%
import pandas as pd
df = pd.read_csv('Boston.csv')
df.head(2)
# Out:
#   CRIME   ZN  INDUS  CHAS    NOX     RM   AGE     DIS   RAD  TAX  PTRATIO  \
# 0  high  0.0  18.10     0  0.718  3.561  87.9  1.6132  24.0  666     20.2
# 1   low  0.0   8.14     0  0.538  5.950  82.0  3.9900   4.0  307     21.0
#
#        B  LSTAT  PRICE
# 0  354.7   7.12   27.5
# 1  232.6  27.71   13.2

# %%
df2=df.fillna(df.mean(numeric_only=True))

# %%
dummy = pd.get_dummies(df2['CRIME'], drop_first=True, dtype=int)
df3 = df2.join(dummy)
df3 = df3.drop(['CRIME'], axis=1)

df3.head(2)
# Out:
#     ZN  INDUS  CHAS    NOX     RM   AGE     DIS   RAD  TAX  PTRATIO      B  \
# 0  0.0  18.10     0  0.718  3.561  87.9  1.6132  24.0  666     20.2  354.7
# 1  0.0   8.14     0  0.538  5.950  82.0  3.9900   4.0  307     21.0  232.6
#
#    LSTAT  PRICE  low  very_low
# 0   7.12   27.5    0         0
# 1  27.71   13.2    1         0

# %%
from sklearn.preprocessing import StandardScaler

df4=df3.astype('float')
sc=StandardScaler()
sc_df=sc.fit_transform(df4)

# %%
from sklearn.decomposition import PCA

model = PCA(n_components = 2, whiten = True)
model.fit(sc_df)
print(model.components_[0])
print('-----')
print(model.components_[1])
# Out:
# [-0.2258543   0.35923465  0.04220985  0.3499321  -0.19485285  0.29792086
#  -0.29980115  0.30726517  0.32822012  0.16246983 -0.18251937  0.27543839
#  -0.2018449   0.03831172 -0.31492126]
# -----
# [-0.1533893   0.02835867  0.19795373  0.13817925  0.4047141   0.20058802
#  -0.29340246 -0.1027543  -0.11546952 -0.34046929  0.05661836 -0.17845386
#   0.44390529  0.42253976 -0.27716437]

# %%
new = model.transform(sc_df)

new_df = pd.DataFrame(new)
new_df.head(3)

# %%
new_df.columns = ['PC1', 'PC2']
df5 = pd.DataFrame(sc_df, columns = df4.columns)
df6 = pd.concat([df5, new_df], axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 new_df.columns = ['PC1', 'PC2']
#       2 df5 = pd.DataFrame(sc_df, columns = df4.columns)
#       3 df6 = pd.concat([df5, new_df], axis=1)
#
# NameError: name 'new_df' is not defined

# %%
df_corr = df6.corr()
df_corr.loc[:'very_low', 'PC1':]
